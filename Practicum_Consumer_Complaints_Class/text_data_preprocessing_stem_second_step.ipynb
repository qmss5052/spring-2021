# %% [markdown]
# # This notebook is designed for preparing text data for furthur analyses

# %% [markdown]
# ## First, I read in the original complaints.csv data

# %%
# !pip install swifter

# %%
import numpy as np
import pandas as pd
import swifter
import nltk 
import sklearn 
import string

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer
from tqdm.notebook import tqdm
from nltk.stem import PorterStemmer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
narratives_token_before_stem = pd.read_csv("/content/drive/MyDrive/QMSS Practicum 2021/narratives_token.csv")

# %%
narratives_token_before_stem.columns
# Out:
# Index(['Unnamed: 0', 'Date_received', 'Product', 'Sub_product', 'Issue',
#        'Sub-issue', 'Consumer_complaint_narrative', 'Company_public_response',
#        'Company', 'State', 'Tags', 'Consumer_consent_provided?',
#        'Date_sent_to_company', 'Company_response_to_consumer',
#        'Timely_response?', 'Consumer_disputed?',
#        'Consumer_complaint_narrative_token',
#        'Consumer_complaint_narrative_length'],
#       dtype='object')

# %%
narratives_token_before_stem = narratives_token_before_stem[['Date_received', 'Product', 'Sub_product', 'Issue',
       'Sub-issue', 'Consumer_complaint_narrative', 'Company_public_response',
       'Company', 'State', 'Tags', 'Consumer_consent_provided?',
       'Date_sent_to_company', 'Company_response_to_consumer',
       'Timely_response?', 'Consumer_disputed?',
       'Consumer_complaint_narrative_token',
       'Consumer_complaint_narrative_length']]

# %%
narratives_token_before_stem.head()
# Out:
#   Date_received  ... Consumer_complaint_narrative_length
# 0    2019-09-24  ...                                   9
# 1    2019-11-08  ...                                  29
# 2    2019-09-15  ...                                  72
# 3    2021-02-02  ...                                  24
# 4    2019-07-26  ...                                  74
#
# [5 rows x 17 columns]

# %% [markdown]
# ## In the next step, I will stem the narratives

# %%
narratives_token_before_stem['Consumer_complaint_narrative'] = narratives_token_before_stem['Consumer_complaint_narrative'].astype(str)

# %%
def my_stem_a(var):
    from nltk.stem import PorterStemmer
    stem = PorterStemmer()
    tmp = var.split()
    tmp = [stem.stem(word) for word in tmp]
    tmp = ' '.join(tmp)
    return tmp

# %%
narratives_token_before_stem['Consumer_complaint_narrative'] =narratives_token_before_stem['Consumer_complaint_narrative'].swifter.apply(my_stem_a)

# %%
narratives_token_before_stem.head()
# Out:
#   Date_received  ... Consumer_complaint_narrative_length
# 0    2019-09-24  ...                                   9
# 1    2019-11-08  ...                                  29
# 2    2019-09-15  ...                                  72
# 3    2021-02-02  ...                                  24
# 4    2019-07-26  ...                                  74
#
# [5 rows x 17 columns]

# %%
  >>> import nltk
  >>> nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
narratives_token_before_stem['Consumer_complaint_narrative_token']=narratives_token_before_stem['Consumer_complaint_narrative'].swifter.apply(word_tokenize)

# %%
narratives_token_before_stem.head()
# Out:
#   Date_received  ... Consumer_complaint_narrative_length
# 0    2019-09-24  ...                                   9
# 1    2019-11-08  ...                                  29
# 2    2019-09-15  ...                                  72
# 3    2021-02-02  ...                                  24
# 4    2019-07-26  ...                                  74
#
# [5 rows x 17 columns]

# %%
narratives_token_before_stem['Consumer_complaint_narrative_length'] = narratives_token_before_stem['Consumer_complaint_narrative_token'].str.len()

# %%
narratives_token_before_stem.head()
# Out:
#   Date_received  ... Consumer_complaint_narrative_length
# 0    2019-09-24  ...                                   9
# 1    2019-11-08  ...                                  29
# 2    2019-09-15  ...                                  72
# 3    2021-02-02  ...                                  24
# 4    2019-07-26  ...                                  74
#
# [5 rows x 17 columns]

# %% [markdown]
# ## Next, I save this file

# %%
narratives_token_before_stem.to_csv('/content/drive/MyDrive/QMSS Practicum 2021/narratives_token.csv')
